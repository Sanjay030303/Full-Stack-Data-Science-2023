# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjay030303/Full-Stack-Data-Science-2023/blob/main/Programming_Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. What are the two values of the Boolean data type? How do you write them?
boolean_true = True
boolean_false = False

# 2. What are the three different types of Boolean operators?
# - and (logical AND)
# - or (logical OR)
# - not (logical NOT)

# 3. Truth tables for Boolean operators:
# AND (and)
# True and True = True
# True and False = False
# False and True = False
# False and False = False

# OR (or)
# True or True = True
# True or False = True
# False or True = True
# False or False = False

# NOT (not)
# not True = False
# not False = True

# 4. Values of the following expressions:
exp1 = (5 > 4) and (3 == 5)  # False
exp2 = not (5 > 4)  # False
exp3 = (5 > 4) or (3 == 5)  # True
exp4 = not ((5 > 4) or (3 == 5))  # False
exp5 = (True and True) and (True == False)  # False
exp6 = (not False) or (not True)  # True

# 5. Six comparison operators:
# - == (equal to)
# - != (not equal to)
# - < (less than)
# - > (greater than)
# - <= (less than or equal to)
# - >= (greater than or equal to)

# 6. Difference between equal to (==) and assignment (=) operators:
# - == is used for comparison and checks if two values are equal.
# - = is used for assignment and assigns a value to a variable.

# Example:
x = 5  # Assignment
if x == 5:  # Comparison using equal to operator

# 7. Identify the three blocks in this code:
spam = 0
if spam == 10:  # Block 1
    print('eggs')
if spam > 5:  # Block 2
    print('bacon')
else:  # Block 3
    print('ham')
print('spam')
print('spam')

# 8. Code that prints different messages based on the value of spam:
spam = 1
if spam == 1:
    print('Hello')
elif spam == 2:
    print('Howdy')
else:
    print('Greetings!')

# 9. If your program is stuck in an endless loop, press Ctrl+C to interrupt it.

# 10. Difference between break and continue:
# - break: Exits the current loop.
# - continue: Skips the current iteration and continues with the next iteration of the loop.

# 11. Difference between range(10), range(0, 10), and range(0, 10, 1):
# - range(10) generates numbers from 0 to 9 (default start is 0, default step is 1).
# - range(0, 10) generates numbers from 0 to 9 (explicitly specifying start, default step is 1).
# - range(0, 10, 1) is equivalent to range(0, 10).

# 12. Printing numbers 1 to 10 using for and while loops:
# Using for loop:
for i in range(1, 11):
    print(i)

# Using while loop:
num = 1
while num <= 10:
    print(num)
    num += 1

# 13. Calling a function named bacon() inside a module named spam:
# First, import the module:
import spam

# Then, call the function:
spam.bacon()
